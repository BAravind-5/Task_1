# %% [markdown]
# <a href="https://colab.research.google.com/github/BAravind-5/Task_1/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_shopify = pd.read_csv('/content/shopify_trending_products_2025.csv')
df_shopify.head()
# Out:
#        Product_ID                           Product_Name           Category  \
# 0  PROD-2025-0001       Loaded Tea At-Home Beverage Pack    Food & Beverage
# 1  PROD-2025-0002  Protein Coffee On-The-Go Energy Drink    Food & Beverage
# 2  PROD-2025-0003       Whitening Strips 7-Day Treatment  Beauty & Skincare
# 3  PROD-2025-0004                   5-1 Full Body Shaver  Beauty & Skincare
# 4  PROD-2025-0005     Newborn Training Pants Baby Shorts               Baby
#
#              Subcategory  Estimated_Total_Units_Sold_in_2025  \
# 0              Beverages                             1651289
# 1              Beverages                             1466551
# 2          Personal Care                              953072
# 3  Personal Care Gadgets                              509346
# 4  Organic Baby Clothing                              835510
#
#    Estimated_Revenue_in_2025_USD Price_Range_USD  Trend_Score  \
# 0                      4953867.0         $3.0-$4         99.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.shape
# Out:
# (17000, 9)
